# %%
import os
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from sklearn.naive_bayes import BernoulliNB,MultinomialNB
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_dataset():
    directory = 'dataset'
    files = os.listdir(directory)
    classes = []
    for file in files:
        classes.append(file.rstrip('.tsv'))
    
    dfs = []
    for file in files:
        file_path = 'dataset/'+file
        df = pd.read_csv(file_path, sep='\t')
        dfs.append(df)
    df = pd.concat(dfs, ignore_index=True)
    df = df.drop_duplicates()
    df = df.dropna()
    return df

# %%
def plotting(macroBNB, macroMNB, microBNB, microMNB, accBNB, accMNB):
    plt.figure(figsize=(14, 8))

    plt.subplot(2, 2, 1)
    plt.plot(macroBNB, marker='o', label='macroBNB')
    plt.plot(macroMNB, marker='o', label='macroMNB')
    plt.title('Macro Metrics')
    plt.xlabel('Fold')
    plt.ylabel('Score')
    plt.legend()
    plt.axhline(y=macroBNB.mean(), color='r', linestyle='--', label='macroBNB mean')
    plt.axhline(y=macroMNB.mean(), color='b', linestyle='--', label='macroMNB mean')
    plt.legend()

    plt.subplot(2, 2, 2)
    plt.plot(microBNB, marker='o', label='microBNB')
    plt.plot(microMNB, marker='o', label='microMNB')
    plt.title('Micro Metrics')
    plt.xlabel('Fold')
    plt.ylabel('Score')
    plt.legend()
    plt.axhline(y=microBNB.mean(), color='r', linestyle='--', label='microBNB mean')
    plt.axhline(y=microMNB.mean(), color='b', linestyle='--', label='microMNB mean')
    plt.legend()

    plt.subplot(2, 2, 3)
    plt.plot(accBNB, marker='o', label='accBNB')
    plt.plot(accMNB, marker='o', label='accMNB')
    plt.title('Accuracy Metrics')
    plt.xlabel('Fold')
    plt.ylabel('Score')
    plt.legend()
    plt.axhline(y=accBNB.mean(), color='r', linestyle='--', label='accBNB mean')
    plt.axhline(y=accMNB.mean(), color='b', linestyle='--', label='accMNB mean')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Orignal data preprocessing

# %%
nltk.download('stopwords')
nltk.download('punkt')

df = get_dataset()
ps = PorterStemmer()
stop_words = set(stopwords.words('english'))


def org_preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text) 
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [ps.stem(word) for word in tokens]
    return text
    
df['Release Year'] = str(df['Release Year'])
df['Content'] = df.apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
df['Content'] = df['Content'].apply(org_preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\11580\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\11580\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
X = df['Content']
y = df['Genre']
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
pipelineBNB = Pipeline(steps=[
    ('preprocessor', CountVectorizer()),
    ('classifier', BernoulliNB())
])

pipelineMNB = Pipeline(steps=[
    ('preprocessor', CountVectorizer()),
    ('classifier', MultinomialNB())
])
macroBNB = cross_val_score(pipelineBNB, X, y, cv=cv, scoring='f1_macro')
macroMNB = cross_val_score(pipelineMNB, X, y, cv=cv, scoring='f1_macro')
microBNB = cross_val_score(pipelineBNB, X, y, cv=cv, scoring='f1_micro')
microMNB = cross_val_score(pipelineMNB, X, y, cv=cv, scoring='f1_micro')
accBNB = cross_val_score(pipelineBNB, X, y, cv=cv, scoring='accuracy')
accMNB = cross_val_score(pipelineMNB, X, y, cv=cv, scoring='accuracy')

plotting(macroBNB,macroMNB,microBNB,microMNB,accBNB,accMNB)

# %% [markdown]
# # Modified Data preprocessing

# %%
df = get_dataset()

modify = r'[^\w\s\'-]'

def preprocess_text(text):
    text = text.lower()
    text = re.sub(modify, '', text) 
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [ps.stem(word) for word in tokens]
    return ' '.join(tokens)
    
def preprocess_name(text):
    text = text.lower()
    text = text.replace(' ', '')
    text = text.replace(',', ' ')
    text = re.sub(modify, '', text) 
    return text
    
df['Release Year'] = str(df['Release Year'])
for col in df.columns:
    if col != 'Genre':
        if col == 'Cast' or col == 'Director':
            df[col] = df[col].apply(preprocess_name)
        else:
            df[col] = df[col].apply(preprocess_text)
df['Content'] = df.apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# %%
X = df['Content']
y = df['Genre']
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
pipelineBNB = Pipeline(steps=[
    ('preprocessor', CountVectorizer()),
    ('classifier', BernoulliNB())
])

pipelineMNB = Pipeline(steps=[
    ('preprocessor', CountVectorizer()),
    ('classifier', MultinomialNB())
])
macroBNB = cross_val_score(pipelineBNB, X, y, cv=cv, scoring='f1_macro')
macroMNB = cross_val_score(pipelineMNB, X, y, cv=cv, scoring='f1_macro')
microBNB = cross_val_score(pipelineBNB, X, y, cv=cv, scoring='f1_micro')
microMNB = cross_val_score(pipelineMNB, X, y, cv=cv, scoring='f1_micro')
accBNB = cross_val_score(pipelineBNB, X, y, cv=cv, scoring='accuracy')
accMNB = cross_val_score(pipelineMNB, X, y, cv=cv, scoring='accuracy')

plotting(macroBNB,macroMNB,microBNB,microMNB,accBNB,accMNB)

# %% [markdown]
# # Apply top-K

# %%
k=1000
pipelineBNB = Pipeline(steps=[
    ('preprocessor', CountVectorizer(max_features=k)),
    ('classifier', BernoulliNB())
])
pipelineMNB = Pipeline(steps=[
    ('preprocessor', CountVectorizer(max_features=k)),
    ('classifier', MultinomialNB())
])
macroBNB = cross_val_score(pipelineBNB, X, y, cv=cv, scoring='f1_macro')
macroMNB = cross_val_score(pipelineMNB, X, y, cv=cv, scoring='f1_macro')
microBNB = cross_val_score(pipelineBNB, X, y, cv=cv, scoring='f1_micro')
microMNB = cross_val_score(pipelineMNB, X, y, cv=cv, scoring='f1_micro')
accBNB = cross_val_score(pipelineBNB, X, y, cv=cv, scoring='accuracy')
accMNB = cross_val_score(pipelineMNB, X, y, cv=cv, scoring='accuracy')

plotting(macroBNB,macroMNB,microBNB,microMNB,accBNB,accMNB)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
from sklearn.feature_selection import SelectKBest, chi2
pipelineSVM = Pipeline(steps=[
    ('preprocessor', vect2),
    ('classifier', SVC())
])
macroSVM = cross_val_score(pipelineSVM, X, y, cv=cv, scoring='f1_macro')
microSVM = cross_val_score(pipelineSVM, X, y, cv=cv, scoring='f1_micro')
accSVM = cross_val_score(pipelineSVM, X, y, cv=cv, scoring='accuracy')

# %%
# Plot the results
plt.figure(figsize=(14, 8))

# Plot Macro F1
plt.subplot(2, 2, 1)
plt.plot(macroSVM, marker='o', label='macroSVM')
plt.plot(macroBNB, marker='o', label='macroBNB')
plt.plot(macroMNB, marker='o', label='macroMNB')
plt.title('Macro F1 Score')
plt.xlabel('Fold')
plt.ylabel('Score')
plt.legend()

# Plot Micro F1
plt.subplot(2, 2, 2)
plt.plot(microSVM, marker='o', label='microSVM')
plt.plot(microBNB, marker='o', label='microBNB')
plt.plot(microMNB, marker='o', label='microMNB')
plt.title('Micro F1 Score')
plt.xlabel('Fold')
plt.ylabel('Score')
plt.legend()

# Plot Accuracy
plt.subplot(2, 2, 3)
plt.plot(accSVM, marker='o', label='accSVM')
plt.plot(accBNB, marker='o', label='accBNB')
plt.plot(accMNB, marker='o', label='accMNB')
plt.title('Accuracy')
plt.xlabel('Fold')
plt.ylabel('Score')
plt.legend()

plt.tight_layout()
plt.show()

# %%
user1 = pd.read_csv('user1.tsv', sep='\t')
user2 = pd.read_csv('user2.tsv', sep='\t')
